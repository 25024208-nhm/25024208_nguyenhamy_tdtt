# %% [markdown]
# ### Bài 1:
# Nhập vào số nguyên n, in ra màn hình số gấp đôi của n

# %%
n = int(input("Nhap vao mot so nguyen:"))
print(n*n)
print(n**2)
# Out:
# 49
# 49

# %% [markdown]
# ### Bài 2:
# Một khu đất hình chữ nhật có chiều rộng a, chiều dài b. Người ra xây một khu vui chơi hình tròn tại vị trí trung tâm khu đất như hình vẽ.
# Nhập vào a, b. Hãy tính phần diện tích còn để trồng cây xung quanh là bao nhiêu. Biết pi = 3.14, lấy kết quả đến 2
# chữ số phần thập phân

# %%
a,b = map(int, input().split())
pi = 3.14
if a<b:
    s = a*b-pi*(a/2)**2
else:
    s = a*b-pi*(b/2)**2
print(s)
# Out:
# 4.935

# %% [markdown]
# ### Bài 3:
# Viết chương trình nhập vào một “kí tự” c, nếu nó là chữ hoa thì in ra chữ thường tương ứng và ngược lại nếu nó là chữ thường thì in ra chữ hoa tương ứng của nó. (xem
# trước cấu trúc lựa chọn: if….else, ma)

# %%
n = input()
if "A" <= n <= "Z":
    print(chr(ord(n) + 32))
elif "a" <= n <= "z":
    print(chr(ord(n) - 32))
# Out:
# m

# %%
c = input("Nhap vao mot ki tu:")
if c.isupper() == True:
    print(c.lower())
else:
    print(c.upper())
# Out:
# H

# %% [markdown]
# ### Bài 4:
# Viết chương trình nhập vào một “kí tự”, Kiểm tra xem c có phải là kí tự chữ cái không (hoa hoặc thường). Nếu đúng thì in ra “{c} là kí tu alphabet”, nếu sai in ra “{c}
# không phải là kí tự alphabet.

# %%
c = input("Nhap vao mot ki tu:")
if c.isalpha() == True:
    print(f"{c} la ki tu alphabet")
else:
    print(f"{c} khong la ki tu alphabet")
# Out:
# 8 khong la ki tu alphabet

# %% [markdown]
# ### Bài 5:
# Nhập vào chữ cái hoa A, in ra chữ cái thường liền trước chữ cái a thường tương ứng của A. Xét TH khi c = ‘A’ là đặc biệt

# %%
A = input("Nhap vao mot chu cai in hoa:")
a = A.lower()
if a == "a":
    print("z")
else:
    ma_ascii = ord(a)
    ma_ascii_lientruoc = ma_ascii - 1
    print(chr(ma_ascii_lientruoc))
# Out:
# m

# %% [markdown]
# ### Bài 6.
# Nhập vào 3 số a, b, c. Kiểm tra xem đây có phải là cạnh của 1 tam giác không, nếu đúng thì tính diện tích của tam giác đó in ra với 1 chữ số phần thập phân, nếu nó không phải 3 cạnh của tam giác thì in ra “Khong phai 3 canh cua tam giac”.

# %%
import math
a,b,c = map(int, input("Nhap vao 3 so: ").split())
if a+b>c and b+c>a and c+a>b:
    p = (a+b+c)/2
    s = math.sqrt(p*(p-a)*(p-b)*(p-c))
    print("Dien tich tam giac la: ", "{:.1f}".format(s))
else:
    print("Khong phai 3 canh cua tam giac")
# Out:
# Khong phai 3 canh cua tam giac

# %% [markdown]
# ### Bài 7:
# Nhập vào một chuỗi gồm các kí tự thường độ dài >=20, in ra chữ cái thứ năm và thứ chín của chuỗi này.

# %%
s = input("Nhap vao mot chuoi ki tu:")
print(s[4])
print(s[8])
# Out:
# o
# o

# %% [markdown]
# ### Bài 8:
# Nhập vào họ tên chủ hộ và chỉ số điện kế tháng trước và chỉ số điện kế tháng này, tính tiền điện tháng này cho hộ biết:
# - Từ 0 – 50kWh: 1.984 đồng/kWh
# - Bậc 2: Từ 51 – 100 kWh: 2.050 đồng/kWh
# - Bậc 3: Từ 101 – 200 kWh: 2.380 đồng/kWh
# - Bậc 4: Từ 201 – 300 kWh: 2.998 đồng/kWh
# - Bậc 5: Từ 301 – 400 kWh: 3.350 đồng/kWh
# - Bậc 6: Từ 401 trở đi kWh: 3.460 đồng/kWh
# Tính thêm tiền VAT 8%. Chỉ lấy đến đơn vị đồng

# %%
Ten_chu_ho = input("Nhap ten chu ho: ")
Chi_so_thang_truoc = int(input("Nhap chi so thang truoc: "))
Chi_so_thang_nay = int(input("Nhap chi so thang nay: "))
So_dien = Chi_so_thang_nay - Chi_so_thang_truoc

if So_dien<=50:
    Gia_tien = So_dien*1984
elif So_dien<=100:
    Gia_tien = 50*1984 + (So_dien-50)*2050
elif So_dien<=200:
    Gia_tien = 50*1984 + 50*2050 + (So_dien-100)*2380
elif So_dien<=300:
    Gia_tien = 50*1984 + 50*2050 + 100*2380 + (So_dien-200)*2998
elif So_dien<=400:
    Gia_tien = 50*1984 + 50*2050 + 100*2380 + 100*2998 + (So_dien-300)*3350
else:
    Gia_tien = 50*1984 + 50*2050 + 100*2380 + 100*2998 + 100*3350 + (So_dien-400)*3460

print(round(Gia_tien*1.08))
# Out:
# 1855505

# %% [markdown]
# ### 1
# Kiểm tra số chẵn lẻ: Viết chương trình nhập một số nguyên, kiểm tra và in ra số đó là số chẵn hay số lẻ

# %%
n = int(input())
if n % 2 == 0:
    print(f"{n} la so chan")
else:
    print(f"{n} la so le")
# Out:
# 5 la so le

# %% [markdown]
# ### 2
# Kiểm tra số có tận cùng 5 không: Viết chương trình nhập một số nguyên, kiểm tra
# số đó có tận cùng 5 không, nếu đúng in ra “True”, nếu sai in ra “False”.

# %%
n = int(input())
if n % 100000 == 0:
    print("True")
else:
    print("False")
# Out:
# True

# %% [markdown]
# ### 3
# Kiểm tra số có chia hết cho 3 và 5 không: Viết chương trình nhập một số nguyên,
# kiểm tra số đó có chia hết cho 3 và 5 không, nếu đúng in ra “True”, nếu sai in ra
# “False”.

# %%
n = int(input())
if n%3==0 and n%5==0:
    print("True")
else:
    print("False")
# Out:
# False

# %% [markdown]
# ### 4
# Kiểm tra tuổi đủ điều kiện bầu cử: Viết chương trình nhập năm sinh của một
# người, kiểm tra xem người đó có đủ 18 tuổi để đi bầu cử hay không.

# %%
n = int(input("Nhap nam sinh: "))
if 2026 - n >= 18:
    print("Du tuoi bau cu")
else:
    print("Khong du tuoi bau cu")
# Out:
# Khong du tuoi bau cu

# %% [markdown]
# ### 5
# So sánh 2 số: Viết chương trình nhập vào hai số, in ra số lớn hơn hoặc thông báo nếu hai số bằng nhau

# %%
a,b = map(int, input("Nhap vao 2 so:").split())
if a==b:
    print("Hai so bang nhau")
elif a>b:
    print(a)
else:
    print(b)
# Out:
# 9

# %% [markdown]
# ### 6
# Kiểm tra ký tự nhập vào là chữ hay số: Viết chương trình nhập một ký tự, kiểm tra xem ký tự đó là chữ cái hay số.

# %%
n = input()
if n.isalpha() == True:
    print(f"Ky tu {n} la chu cai")
elif n.isdigit():
    print(f"Ky tu {n} la so")
# Out:
# Ky tu m la chu cai

# %% [markdown]
# ### 7
# Tính điểm học lực
# Nhập điểm (0-10), phân loại học lực theo quy tắc:
# >=8: Giỏi; >=6.5 và <8: Khá; >=5 và <6.5: Trung bình; <5: Yếu

# %%
n = float(input("Nhap diem cua ban (0-10): "))
if n >= 8:
    print("Gioi")
elif n >= 6.5:
    print("Kha")
elif n >= 5:
    print("Trung binh")
else:
    print("Yeu")
# Out:
# Yeu

# %% [markdown]
# ### 8
# Kiểm tra năm nhuận: Viết chương trình nhập năm, kiểm tra xem năm đó có phải năm nhuận hay không. (Năm nhuận nếu chia hết cho 400 hoặc chia hết cho 4 nhưng không chia hết cho 100)

# %%
n = int(input("Nhap nam: "))
if n%400==0 or (n%4==0 and n%100!=0):
    print(f"Nam {n} la nam nhuan")
else:
    print(f"Nam {n} khong phai nam nhuan")
# Out:
# Nam 2024 la nam nhuan

# %% [markdown]
# ### 9
# Chuyển đổi số thành chữ số: Nhập một số nguyên từ 0 đến 9, in ra tên chữ số
# tương ứng (0 -> "Không", 1 -> "Một", ...) – Xem trước match …case

# %%
n = int(input("Nhap mot so nguyen (0-9): "))
match n:
    case 0:
        print("Khong")
    case 1:
        print("Mot")
    case 2:
        print("Hai")
    case 3:
        print("Ba")
    case 4:
        print("Bon")
    case 5:
        print("Nam")
    case 6:
        print("Sau")
    case 7:
        print("Bay")
    case 8:
        print("Tam")
    case 9:
        print("Chin")
# Out:
# Bay

# %%
n = int(input())
def digit(n):
    match n:
        case 0: return "Khong"
        case 1: return "Mot"
        case 2: return "Hai"
        case 3: return "Ba"
        case 4: return "Bon"
        case 5: return "Nam"
        case 6: return "Sau"
        case 7: return "Bay"
        case 8: return "Tam"
        case 9: return "Chin"
        case _: return "Khong tim thay"
print(digit(n))
# Out:
# Khong tim thay

# %% [markdown]
# ### 10.
# Kiểm tra điểm thi xem có qua môn hay phải học lại: Nhập điểm thi, nếu điểm >=4 thì in "Qua môn", ngược lại in "Học lại".

# %%
n = float(input("Nhap diem cua ban: "))
if n >= 4:
    print("Qua mon")
else:
    print("Hoc lai")
# Out:
# Qua mon

# %% [markdown]
# ### 11.
# Kiểm tra năm sinh và tính tuổi: Nhập năm sinh, tính tuổi hiện tại (giả sử năm hiện tại là 2025), và kiểm tra xem người đó có đủ 18 tuổi hay chưa

# %%
n = int(input("Nhap nam sinh cua ban: "))
tuoi = 2025 - n
print(f"Nam nay ban {tuoi} tuoi")
if tuoi > 18:
    print("Ban da tren 18 tuoi")
elif tuoi == 18:
    print("Ban da du 18 tuoi")
else:
    print("Ban chua du 18 tuoi")
# Out:
# Nam nay ban 18 tuoi
# Ban da du 18 tuoi

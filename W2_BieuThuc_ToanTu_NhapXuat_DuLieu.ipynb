# %% [markdown]
# ### W2A1
# Hãy viết chương trình in ra dòng chữ "Hello World!"

# %%
print("Hello World!")
print("Hello", "World!")
print("Hello", "World!", sep = "/")
print("Hello",)
print("World!")
# Out:
# Hello World!
# Hello World!
# Hello/World!
# Hello
# World!

# %% [markdown]
# ### W2A2 [User Input]
# Viết chương trình nhận đầu vào là tên người từ bàn phím và in ra màn hình lời chào tương ứng.

# %%
name = input("Ten b la gi?")
print("Hi", name)
print(f"Hi, {name}!")
# Out:
# Hi My
# Hi, My!

# %% [markdown]
# ### W2A3 [ModAndDiv]
# Viết chương trình nhận vào hai số nguyên a, b từ bàn phím. In ra tổng, hiệu, tích, phần nguyên, phần dư và kết quả chia thực của phép chia a cho b (lấy đến 2 chữ số phần thập phân)

# %%
a = int(input())
b = int(input())
print(a+b)
print(a-b)
print(a*b)
print(a//b)
print(a%b)
print("{:.2f}".format(a/b))
# Out:
# 11
# 7
# 18
# 4
# 1
# 4.50

# %% [markdown]
# ### W2A4 [AverageOfSix]
# Đầu vào: Trong bài tập này, dữ liệu vào chỉ gồm duy nhất một dòng bao gồm 6 số thể hiện cho 6 đầu điểm a1, b1, c1, a2, b2, a3 theo đúng thứ tự đó. Trong đó, hai đầu điểm liên tiếp nhau sẽ được phân tách nhau bởi duy nhất 1 dấu cách.
# Đầu ra: Đầu ra là giá trị điểm trung bình môn học của 6 môn học, lấy đến 1 chữ số phần thập phân.

# %%
a1,b1,c1,a2,b2,c2 = map(int, input().split())
TB = ((a1+b1+c1)+(a2+b2)*2+c2*3)/10
print("{:.1f}".format(TB))
# Out:
# 4.2

# %% [markdown]
# ### W2A5 [Exponentiation]
# Nhập vào hai số a, b(int) cách nhau một dấu cách, tính và in ra kết quả a mũ b

# %%
a,b = map(int, input().split())
print(a**b)
# Out:
# 8

# %% [markdown]
# ### W2A6 [StringDataType]
# Hãy nhập vào một kí tự chữ cái thường ‘a’…’z’, in ra mã Unicode của nó sau đó chuyển nó thành kí tự hoa tương ứng, in kí tự hoa này ra màn hình

# %%
n = input("Nhap vao 1 chu cai thuong: ")
ma_chu_thuong = ord(n)
print(ma_chu_thuong)
ma_chu_hoa = ma_chu_thuong - 32
print(chr(ma_chu_hoa))
# Out:
# 110
# N

# %% [markdown]
# ### W2A7 [Operations]
# Hãy in ra kết quả của hai biểu thức sau:
# A = ((13 ** 2) * 3) + 5 và B = 13**2*3 + 5

# %%
A = ((13**2)*3)+5
B = 13**2*3+5
print(A)
print(B)
# Out:
# 512
# 512

# %% [markdown]
# ### W2A8 [CelsiusTranfer]
# Dựa vào nhiệt độ Celcius được nhập từ bàn phím, hãy chuyển sang độ F theo công thức: F = 9/5*C + 32 và in ra màn hình kết quả. Kết quả làm tròn đến hai chữ số thập phân đằng sau dấu phẩy

# %%
C = int(input("Nhap nhiet do Celcius: "))
F = 9/5*C + 32
print("{:.2f}".format(F))
# Out:
# 86.00

# %% [markdown]
# ### W2A9 [ShoppingOnline]
# Viết chương trình tính tổng số tiền mà Đạt phải trả để mua
# được chiếc đồng hồ trên (USD). Kết quả làm tròn đến hai chữ số thập phân.

# %%
x = int(input())
tong_tien = (x+10) + x*0.3 + x*0.1
print("{:.2f}".format(tong_tien))
print(f"{tong_tien:.2f}")
# Out:
# 103.80
# 103.80

# %% [markdown]
# ### W2A10 [Friend Names]
# Viết chương trình nhập vào tên 3 người từ bàn phím.
# In ra màn hình tên theo thứ tự đảo ngược

# %%
ten1, ten2, ten3 = input().split()
print(f"Hi {ten3}, {ten2}, {ten1}.")
# Out:
# Hi m, h, n.

# %% [markdown]
# ### W2A11
# Viết chương trình chuyển từ giờ và phút sang giây
# Đầu vào gồm hai giá trị chứa số giờ \h và số phút \m:
# Đầu ra: In ra màn hình một dòng duy nhất số giờ và phút được chuyển sang đơn vị giây.

# %%
h, m = map(int, input().split())
print(f"{h} gio {m} phut = {(h*60+m)*60}")
# Out:
# 2 gio 30 phut = 9000

# %% [markdown]
# ### W2A12
# Cho một khối Rubik có độ dài cạnh là n, hãy trả về số lượng miếng dán riêng lẻ cần thiết để bao phủ toàn bộ khối lập phương

# %%
n = int(input())
print(f"So mieng dan can la {n**2*6}")
# Out:
# So mieng dan can la 24

# %% [markdown]
# ### W2A13
# Nhập vào từ bàn phím hai số nguyên dương \a và \b, viết chương trình trả về hàng đơn vị của phép tính tích giữa \a và \b.

# %%
a, b = map(int, input().split())
tich = a*b 
print(tich%10)
# Out:
# 2

# %% [markdown]
# ### W2A14
# Viết chương trình hoán đổi giá trị giữa hai số a và b mà không cần khai báo thêm một biến/ hàm nào khác

# %%
a, b = map(int, input().split())
a, b = b, a
print (a, b)
# Out:
# 4 3

# %% [markdown]
# ### W2A15
# Viết chương trình nhận vào một số nguyên dương n và trả về "số sao" thứ n.
# Một "số sao" là một số hình học trung tâm đại diện cho một hình lục giác có tâm (ngôi sao
# sáu cánh), giống như hình dạng được sử dụng trong trò chơi cờ Trung Quốc.

# %%
n = int(input())

# %% [markdown]
# ### W2A16 [SeasonsInYear]

# %%
print("Spring")
print("Summer")
print("Autumn")
print("Winter")
print("Spring\nSummer\nAutumn\nWinter")
# Out:
# Spring
# Summer
# Autumn
# Winter
# Spring
# Summer
# Autumn
# Winter

# %% [markdown]
# ### W2A17 [DrawTriangle]

# %%
print("*")
print("***")
print("*****")
# Out:
# *
# ***
# *****

# %% [markdown]
# ### W2A18 [Banner]
# Viết chương trình in ra dòng chữ "TDTT" như sau:

# %%
print("### # #  ### ###")
print(" #  #  #  #   # ")
print(" #  #   # #   # ")
print(" #  #  #  #   # ")
print(" #  # #   #   # ")
# Out:
# ### # #  ### ###
#  #  #  #  #   #
#  #  #   # #   #
#  #  #  #  #   #
#  #  # #   #   #

# %% [markdown]
# ### W2A19  [Days of the week]
# Viết chương trình in ra các ngày trong một tuần bằng tiếng Anh. Mỗi ngày in trên một dòng

# %%
print("Mondey\nTuesdaay\nWednesday\nThursday\nFriday\nSaturday\nSunday")
# Out:
# Mondey
# Tuesdaay
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %% [markdown]
# ### W2A20 [Months of the year]
# Viết chương trình in ra các tháng trong một năm bằng tiếng Anh. Mỗi tháng in trên một
# dòng, bắt đầu từ "January"

# %%
print("January\nFebruary\nMarch\nApril\nMay\nJune\nJuly\nAugust\nSeptember\nOctober\nNovember\nDecember")
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %% [markdown]
# ### W2A21 [Ten Hello World]
# Viết chương trình in ra màn hình dòng chữ "Hello, world" 10 lần

# %%
for i in range(10):
    print("Hello, world")
# Out:
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
